# %%
import catan
import pandas as pd
pd.options.display.precision = 2
# %matplotlib inline

# %%
from catan.games import tiles as testtiles

# %%
brd = catan.Board(testtiles[1])

# %%
brd.plot()
brd.plot_best('pipworth')

# %%
brd.best('pipworth').head()
# Out:
#      pips  relpips  pipworth  ave_potential  blocking  total  \
# x y
# 5 1    13    13.72     13.72          10.50     11.63  62.58
# 6 1    11    13.38     13.38          10.76     11.58  60.09
# 3 4    12    12.83     12.83           8.77      9.73  56.16
# 7 1    12    12.78     12.78          10.97     10.80  59.33
# 5 2    11    11.61     11.61          11.64     10.91  56.78
#
#                       tiles
# x y
# 5 1   clay 5 sheep 6 rock 9
# 6 1  clay 5 wheat 10 rock 9
# 3 4  wheat 5 clay 10 wood 8
# 7 1  wood 8 clay 5 wheat 10
# 5 2  rock 11 clay 5 sheep 6

# %%
brd.settle(8, 2, 'blue')
brd.settle(6, 3, 'blue')
brd.settle(3, 1, 'blue')

# %%
# pl = catan.Player('blue', 1)
# pl.settle(brd.verts[8, 2])
# pl.settle(brd.verts[6, 3])
# pl.settle(brd.verts[3,1])
# pl.verts

# %%
brd.best('pipworth', 'blue')
# Out:
#       pips  relpips  pipworth  ave_potential  blocking  total  \
# x  y
# 5  1    13    13.72      3.43           2.63      2.91  35.69
# 6  1    11    13.38      3.34           2.69      2.89  33.30
# 3  4    12    12.83      3.21           2.19      2.43  32.66
# 7  1    12    12.78      3.20           2.74      2.70  33.42
# 5  2    11    11.61      2.90           2.91      2.73  31.16
# 3  3    10    10.16      2.54           2.38      2.53  27.61
# 4  4     8    10.07      2.52           2.39      2.22  25.20
#    2     9     9.13      2.28           2.95      2.39  25.75
# 2  4     9     8.96      2.24           2.53      1.82  24.55
#    3    10     8.90      2.23           2.68      1.93  25.74
# 4  3     7     8.64      2.16           2.72      2.35  22.87
# 6  0     7     8.22      2.06           3.31      1.80  22.39
# 9  3     7     7.85      1.96           2.45      1.53  20.79
# 5  4     8     7.64      1.91           2.38      1.58  21.50
# ...

# %%
brd.plot()
brd.plot_best()

# %%
brd.relpips2(3, 1, pl)
# Out:
# 1.7834999999999999

# %%
brd.relpips2(3, 1, pl.verts)
# Out:
# 1.7834999999999999

# %%
brd.plot()
brd.plot_best()

# %%
brd.best('relpips2', pl)
# Out:
#       pips  relpips  relpips2  ave_potential  blocking  total  \
# x  y
# 5  1    13    13.72      3.43           2.63      2.91  35.69
# 6  1    11    13.38      3.34           2.69      2.89  33.30
# 3  4    12    12.83      3.21           2.19      2.43  32.66
# 7  1    12    12.78      3.20           2.74      2.70  33.42
# 5  2    11    11.61      2.90           2.91      2.73  31.16
# 3  3    10    10.16      2.54           2.38      2.53  27.61
# 4  4     8    10.07      2.52           2.39      2.22  25.20
#    2     9     9.13      2.28           2.95      2.39  25.75
# 2  4     9     8.96      2.24           2.53      1.82  24.55
#    3    10     8.90      2.23           2.68      1.93  25.74
# 4  3     7     8.64      2.16           2.72      2.35  22.87
# 6  0     7     8.22      2.06           3.31      1.80  22.39
# 9  3     7     7.85      1.96           2.45      1.53  20.79
# 5  4     8     7.64      1.91           2.38      1.58  21.50
# ...
