# %%
import catan
import numpy as np
import pandas as pd
pd.options.display.precision = 2
pd.options.display.show_dimensions = True
# %matplotlib inline

# %%
np.dot([2,3], [4,8])
# Out:
# 32

# %%
brd = catan.Board.random()

# %%
brd.plot()
brd.plot_best()

# %%
brd.best()
# Out:
#       pips  relpips  relpips2  ave_potential  blocking  total  \
# x  y
# 6  4     9    12.76     11.89           9.21      6.67  49.53
# 4  1    10    12.18     12.18          10.96     10.05  55.38
# 5  1     8    12.04     12.04          10.11     11.37  53.55
# 6  1    10    11.63     11.63          11.24      9.99  54.49
# 5  4     7    10.73     10.73           9.46     10.39  48.31
# 4  2    12    10.33     10.33          10.96      9.69  53.30
# 5  2    10    10.29     10.29          11.91     10.75  53.25
# 6  3    12     9.89      9.89          10.05      6.29  48.12
#    2    12     9.89      9.89          11.18      9.99  52.96
# 3  1     9     9.86      9.86          10.15      9.29  48.16
# 7  2    12     9.80      9.10          10.09      9.10  50.09
#    1    12     9.80      9.10          10.09      9.25  50.24
# 3  2     9     9.75      9.75           9.66      9.54  47.69
# 4  4     7     9.42      9.42          10.88      8.41  45.13
# ...
